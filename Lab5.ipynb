# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '*')
plt.plot(x, np.cos(x), '--')
plt.plot(x, np.tan(x), '-')

# %% [markdown]
# ## 2.1 Loading the data into the data frame

# %%
from sklearn import datasets
iris= datasets.load_iris()
df= pd.read_csv(iris.filename)
df.head(5)
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
from sklearn import datasets
iris= datasets.load_iris()
print(iris.filename)
# Out:
# C:\Users\96654\anaconda3\lib\site-packages\sklearn\datasets\data\iris.csv

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
df_with_delimiter=pd.read_csv('C:\\Users\\96654\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\data\\iris.csv'
                        , delimiter=',', header= 0,
                        names=['sepal length(cm)', 'sepal width (cm)', 'petal length (cm)', 'petalwidth (cm)','target class'])

df_with_delimiter.head()
# Out:
#    sepal length(cm)  sepal width (cm)  petal length (cm)  petalwidth (cm)  \
# 0               5.1               3.5                1.4              0.2
# 1               4.9               3.0                1.4              0.2
# 2               4.7               3.2                1.3              0.2
# 3               4.6               3.1                1.5              0.2
# 4               5.0               3.6                1.4              0.2
#
#    target class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_with_delimiter.describe()
# Out:
#        sepal length(cm)  sepal width (cm)  petal length (cm)  petalwidth (cm)  \
# count        150.000000        150.000000         150.000000       150.000000
# mean           5.843333          3.057333           3.758000         1.199333
# std            0.828066          0.435866           1.765298         0.762238
# min            4.300000          2.000000           1.000000         0.100000
# 25%            5.100000          2.800000           1.600000         0.300000
# 50%            5.800000          3.000000           4.350000         1.300000
# 75%            6.400000          3.300000           5.100000         1.800000
# max            7.900000          4.400000           6.900000         2.500000
#
#        target class
# count    150.000000
# mean       1.000000
# std        0.819232
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000

# %%
print(df_with_delimiter["target class"].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: target class, dtype: int64

# %%
df_with_delimiter["target class"].hist()
# Out:
# <AxesSubplot:>

# %%
for ojha, feature in enumerate(list(df_with_delimiter.columns)[:-1]):

  fg = sns.FacetGrid(df_with_delimiter, hue='target class', height=5)

  fg.map(sns.histplot, feature).add_legend()

  plt.show()

# %%
sns.boxplot(x='target class' ,y='petal length (cm)', data=df_with_delimiter)
plt.show()

# %%
sns.violinplot(x='target class' ,y='petal length (cm)', data=df_with_delimiter, size = 40)
plt.show()

# %%
df_with_delimiter.plot(kind='scatter',x='sepal length(cm)',y='sepal width (cm)', c= 'g')
plt.show()

# %%
sns.set_style("whitegrid");
sns.pairplot(df_with_delimiter,vars = ['sepal length(cm)', 'sepal width (cm)', 'petal length (cm)', 'petalwidth (cm)','target class'], hue = 'target class', diag_kind = 'kde',
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'}, size = 2) 
plt.show()
# Out:
# C:\Users\96654\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\96654\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\96654\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\96654\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
